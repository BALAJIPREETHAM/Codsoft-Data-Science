# %% [markdown]
# ## Codsoft Data science Task 5
#
# Name : Danthamala Balaji Preetham

# %% [markdown]
# # CREDIT CARD FRAUD DETECTION
#
# Build a machine learning model to identify fraudulent credit card transactions.Preprocess and normalize the transaction data, handle class imbalance issues, and split the dataset into training and testing sets.Train a classification algorithm, such as logistic regression or random forests, to classify transactions as fraudulent or genuine Evaluate the model's performance using metrics like precision, recall and F1-score, and consider techniques like oversampling or undersampling for improving results.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from sklearn.linear_model import LogisticRegression

# %%
credit_card_data = pd.read_csv(r"/content/creditcard.csv")

# %%
credit_card_data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 37717  39076  1.117749 -1.544665 -0.145357 -1.307482 -1.392833 -0.630833
# 37718  39076  0.758729 -0.483875  0.125488  1.449159 -0.639231 -0.805011
# 37719  39076 -0.474907  0.835804  0.075878 -1.251283  2.492736  3.385419
# 37720  39077 -2.682780 -2.028562  1.745223 -1.157952 -0.143692 -0.807503
# 37721  39077  1.106292 -0.525727  0.926440  0.817696 -1.122177 -0.062703
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 0      0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1     -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2      0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3      0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4      0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# ...         ...       ...       ...  ...       ...       ...       ...
# 37717 -0.563659 -0.038716 -2.173892  ... -0.334155 -1.108220  0.070461
# 37718  0.406994 -0.221212  0.068777  ...  0.210712  0.063091 -0.316636
# 37719  0.169507  0.934749 -0.584224  ... -0.270398 -0.866353 -0.085720
# 37720 -1.154141  0.436917 -0.293442  ...  0.353396  0.968145 -0.776459
# 37721       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# 0      0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1     -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2     -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3     -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4      0.141267 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
# ...         ...       ...       ...       ...       ...     ...    ...
# 37717  0.115485  0.078726 -0.460844 -0.029143  0.029028  183.19    0.0
# 37718  0.394472  0.558720 -0.304812 -0.033008  0.063331  250.00    0.0
# 37719  0.986274 -0.082934  0.084198  0.310936  0.170342    1.49    0.0
# 37720  0.182662 -0.000427 -0.209058  0.256991 -0.585781  102.00    0.0
# 37721       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [37722 rows x 31 columns]

# %%
ccd = credit_card_data

# %%
ccd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37722 entries, 0 to 37721
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    37722 non-null  int64
#  1   V1      37722 non-null  float64
#  2   V2      37722 non-null  float64
#  3   V3      37722 non-null  float64
#  4   V4      37722 non-null  float64
#  5   V5      37722 non-null  float64
#  6   V6      37722 non-null  float64
#  7   V7      37721 non-null  float64
#  8   V8      37721 non-null  float64
#  9   V9      37721 non-null  float64
#  10  V10     37721 non-null  float64
#  11  V11     37721 non-null  float64
#  12  V12     37721 non-null  float64
#  13  V13     37721 non-null  float64
#  14  V14     37721 non-null  float64
#  15  V15     37721 non-null  float64
#  16  V16     37721 non-null  float64
#  17  V17     37721 non-null  float64
#  18  V18     37721 non-null  float64
#  19  V19     37721 non-null  float64
#  20  V20     37721 non-null  float64
#  21  V21     37721 non-null  float64
#  22  V22     37721 non-null  float64
#  23  V23     37721 non-null  float64
#  24  V24     37721 non-null  float64
#  25  V25     37721 non-null  float64
#  26  V26     37721 non-null  float64
#  27  V27     37721 non-null  float64
#  28  V28     37721 non-null  float64
#  29  Amount  37721 non-null  float64
#  30  Class   37721 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 8.9 MB

# %%
ccd.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# no null values, that's great
# distribution of fraudulent and legitimate classes
ccd['Class'].value_counts()
# Out:
# Class
# 0.0    37618
# 1.0      103
# Name: count, dtype: int64

# %%
# visualizing the class distribution in percentage
print((ccd.groupby('Class')['Class'].count()/ccd['Class'].count())*100)
((ccd.groupby('Class')['Class'].count()/ccd['Class'].count())*100).plot.pie()
# Out:
# Class
# 0.0    99.726943
# 1.0     0.273057
# Name: Class, dtype: float64
# <Axes: ylabel='Class'>

# %%
classes = ccd['Class'].value_counts()
normal_value = round(classes[0]/ccd['Class'].count()*100,2)
fraud_values = round(classes[1]/ccd['Class'].count()*100,2)
print(normal_value)
print(fraud_values)
# Out:
# 99.73
# 0.27

# %%
# let's check tthe correlation of the features
corr = ccd.corr()
corr
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# Time    1.000000  0.017817 -0.115667 -0.060288 -0.039296 -0.074106 -0.012260
# V1      0.017817  1.000000 -0.111584  0.286233 -0.092395  0.084105  0.097732
# V2     -0.115667 -0.111584  1.000000 -0.223858  0.115026 -0.105633 -0.023214
# V3     -0.060288  0.286233 -0.223858  1.000000 -0.140251  0.292462 -0.005329
# V4     -0.039296 -0.092395  0.115026 -0.140251  1.000000 -0.064532 -0.043252
# V5     -0.074106  0.084105 -0.105633  0.292462 -0.064532  1.000000  0.090833
# V6     -0.012260  0.097732 -0.023214 -0.005329 -0.043252  0.090833  1.000000
# V7     -0.006050  0.152652 -0.052119  0.334333 -0.092966  0.053985  0.089813
# V8      0.039421 -0.086903  0.060928 -0.275757  0.090215 -0.108779 -0.057475
# V9     -0.336237 -0.038683 -0.005773  0.160022 -0.014563  0.041947  0.046951
# V10     0.111361  0.030846 -0.008436  0.191100 -0.093154  0.137374  0.039092
# V11    -0.201689 -0.030263  0.095902 -0.127220  0.043708 -0.052005 -0.099907
# V12     0.400601  0.052085 -0.122835  0.120925 -0.080486  0.036925  0.012065
# V13    -0.352272  0.008455  0.065816 -0.011075  0.034133  0.051907  0.014098
# V14    -0.271902  0.136922 -0.079127  0.216104 -0.057283  0.085672  0.063653
# V15     0.151653  0.051642  0.053316 -0.169545 -0.104263  0.082753 -0.110145
# V16     0.017531  0.112349 -0.042326  0.014813 -0.140741  0.122885  0.005897
# V17    -0.119962  0.094495 -0.086352  0.168848  0.003852  0.038811  0.026116
# V18    -0.047261 -0.000780 -0.015298  0.029078 -0.027808  0.080408  0.051867
# V19     0.027666  0.009236 -0.013779 -0.038412 -0.023067  0.007805  0.087363
# V20     0.014480 -0.088342 -0.093872 -0.098585  0.026174 -0.020105  0.001890
# V21     0.023977 -0.066936  0.023571  0.000840  0.001601 -0.057700  0.046430
# V22     0.052709 -0.011574 -0.093610  0.241981 -0.004179 -0.072477  0.017426
# V23    -0.007321 -0.066625 -0.017909  0.049262 -0.008036  0.011837 -0.004544
# V24    -0.015493 -0.008550 -0.019256  0.029403 -0.014825 -0.009555  0.017301
# V25     0.052518  0.186100 -0.096462 -0.192161 -0.014468 -0.049813  0.062202
# V26    -0.031422  0.026450 -0.045454  0.059021  0.024185 -0.046523  0.013422
# V27    -0.011783 -0.120735  0.062534 -0.166184  0.064115 -0.109984 -0.021321
# V28     0.000281  0.176195  0.034869  0.059715 -0.029914  0.003799 -0.019242
# Amount  0.074106 -0.220606 -0.516488 -0.173946  0.096238 -0.382210  0.212528
# Class  -0.017828 -0.216471  0.196077 -0.402231  0.213120 -0.198373 -0.096312
#
#               V7        V8        V9  ...       V21       V22       V23  \
# Time   -0.006050  0.039421 -0.336237  ...  0.023977  0.052709 -0.007321
# V1      0.152652 -0.086903 -0.038683  ... -0.066936 -0.011574 -0.066625
# V2     -0.052119  0.060928 -0.005773  ...  0.023571 -0.093610 -0.017909
# V3      0.334333 -0.275757  0.160022  ...  0.000840  0.241981  0.049262
# V4     -0.092966  0.090215 -0.014563  ...  0.001601 -0.004179 -0.008036
# V5      0.053985 -0.108779  0.041947  ... -0.057700 -0.072477  0.011837
# V6      0.089813 -0.057475  0.046951  ...  0.046430  0.017426 -0.004544
# V7      1.000000 -0.134787  0.044997  ... -0.068880  0.001355  0.090767
# V8     -0.134787  1.000000 -0.067522  ... -0.127203  0.054341 -0.053180
# V9      0.044997 -0.067522  1.000000  ... -0.023450  0.009373 -0.035827
# V10     0.155368 -0.142020 -0.051884  ... -0.005486 -0.025115  0.006844
# V11    -0.104040  0.019876  0.082702  ...  0.025513  0.045178  0.033456
# V12     0.162708 -0.067562 -0.240391  ...  0.038093  0.072709 -0.015789
# V13    -0.015553 -0.019685  0.219055  ... -0.025926 -0.046877 -0.003786
# V14     0.089098 -0.065161  0.245380  ... -0.039100 -0.079588  0.033619
# V15     0.072734 -0.029085 -0.201343  ...  0.023037  0.021273  0.015684
# V16     0.119748 -0.059672 -0.068709  ... -0.015216  0.006128 -0.013418
# V17     0.120940 -0.077395  0.209052  ... -0.035881  0.025931  0.044816
# V18     0.085576 -0.026036  0.080332  ... -0.038338 -0.098555  0.003398
# V19    -0.052921  0.020204 -0.036456  ...  0.012382  0.005761 -0.024102
# V20     0.036574  0.054990  0.015899  ... -0.076136  0.021881  0.031487
# V21    -0.068880 -0.127203 -0.023450  ...  1.000000 -0.140790  0.037157
# V22     0.001355  0.054341  0.009373  ... -0.140790  1.000000  0.011605
# V23     0.090767 -0.053180 -0.035827  ...  0.037157  0.011605  1.000000
# V24    -0.002241  0.003131  0.009931  ... -0.010441  0.008993  0.020864
# V25    -0.117281  0.028820  0.095847  ...  0.009661 -0.031621  0.050389
# V26    -0.041814 -0.000763  0.082930  ... -0.018437 -0.067798  0.023133
# V27    -0.152883  0.054021 -0.046852  ...  0.005863 -0.029955 -0.063289
# V28    -0.056514  0.076615 -0.058527  ...  0.108577 -0.040800  0.073528
# Amount  0.351464 -0.076961 -0.024000  ...  0.118421 -0.054968 -0.095552
# Class  -0.319342  0.163140 -0.135874  ...  0.045320 -0.019830 -0.030512
#
#              V24       V25       V26       V27       V28    Amount     Class
# Time   -0.015493  0.052518 -0.031422 -0.011783  0.000281  0.074106 -0.017828
# V1     -0.008550  0.186100  0.026450 -0.120735  0.176195 -0.220606 -0.216471
# V2     -0.019256 -0.096462 -0.045454  0.062534  0.034869 -0.516488  0.196077
# V3      0.029403 -0.192161  0.059021 -0.166184  0.059715 -0.173946 -0.402231
# V4     -0.014825 -0.014468  0.024185  0.064115 -0.029914  0.096238  0.213120
# V5     -0.009555 -0.049813 -0.046523 -0.109984  0.003799 -0.382210 -0.198373
# V6      0.017301  0.062202  0.013422 -0.021321 -0.019242  0.212528 -0.096312
# V7     -0.002241 -0.117281 -0.041814 -0.152883 -0.056514  0.351464 -0.319342
# V8      0.003131  0.028820 -0.000763  0.054021  0.076615 -0.076961  0.163140
# V9      0.009931  0.095847  0.082930 -0.046852 -0.058527 -0.024000 -0.135874
# V10     0.018434 -0.008367 -0.001930 -0.121505 -0.060580 -0.118271 -0.307321
# V11     0.024714 -0.106374  0.025949  0.029803  0.012346 -0.030488  0.233989
# V12     0.015977  0.022935 -0.004744 -0.022958 -0.008058  0.049468 -0.295519
# V13    -0.007558  0.037582  0.023558  0.004258 -0.006483 -0.024402  0.006448
# V14     0.039008 -0.058026  0.029721 -0.055888  0.018125 -0.013197 -0.391956
# V15    -0.004539 -0.096263 -0.040991  0.011343 -0.036324 -0.037432 -0.006563
# V16    -0.000185  0.094955  0.044193 -0.048895 -0.041191 -0.019007 -0.278137
# V17    -0.001231 -0.077555 -0.069193 -0.075614 -0.051237  0.005440 -0.408013
# V18    -0.011281  0.027504  0.030044 -0.036598 -0.001859  0.042175 -0.169408
# V19    -0.003948 -0.012726 -0.026621  0.014441 -0.018746 -0.044154  0.032827
# V20    -0.015219 -0.000006  0.019933 -0.044086  0.165335  0.393809  0.046539
# V21    -0.010441  0.009661 -0.018437  0.005863  0.108577  0.118421  0.045320
# V22     0.008993 -0.031621 -0.067798 -0.029955 -0.040800 -0.054968 -0.019830
# V23     0.020864  0.050389  0.023133 -0.063289  0.073528 -0.095552 -0.030512
# V24     1.000000 -0.028892 -0.010220  0.008873 -0.008197  0.008122 -0.021258
# V25    -0.028892  1.000000 -0.120967  0.044397  0.054963 -0.037689  0.019670
# V26    -0.010220 -0.120967  1.000000 -0.009390  0.016652  0.021464  0.016414
# V27     0.008873  0.044397 -0.009390  1.000000 -0.018631  0.016748  0.110138
# V28    -0.008197  0.054963  0.016652 -0.018631  1.000000  0.005544  0.017246
# Amount  0.008122 -0.037689  0.021464  0.016748  0.005544  1.000000  0.000998
# Class  -0.021258  0.019670  0.016414  0.110138  0.017246  0.000998  1.000000
#
# [31 rows x 31 columns]

# %%
# plotting the heatmap for the correlation
plt.figure(figsize=(27,19))
sns.heatmap(corr, cmap = 'spring', annot= True )
plt.show()

# %%
# separte the data according to type of transaction i.e. fraud or legit
legit = ccd[ccd.Class == 0]

# %%
fraud = ccd[ccd.Class==1]

# %%
legit.Amount.describe()
# Out:
# count    37618.000000
# mean        86.017411
# std        232.957939
# min          0.000000
# 25%          7.300000
# 50%         22.880000
# 75%         77.675000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     103.000000
# mean       90.471165
# std       247.173335
# min         0.000000
# 25%         1.000000
# 50%         3.760000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# we can observe that the mean amount spent for fraud transactions is actually more than for the legit ones
ccd.groupby('Class').describe()
# Out:
#           Time                                                                 \
#          count          mean           std    min      25%      50%       75%
# Class
# 0.0    37618.0  24778.212797  12531.376600    0.0  13921.5  29847.5  34943.75
# 1.0      103.0  20498.291262  10224.604576  406.0  11086.0  20451.0  28641.50
#
#                      V1            ...       V28             Amount  \
#            max    count      mean  ...       75%       max    count
# Class                              ...
# 0.0    39077.0  37618.0 -0.186787  ...  0.075122  5.678671  37618.0
# 1.0    37167.0    103.0 -7.762676  ...  0.483431  1.108933    103.0
#
#
#             mean         std  min  25%    50%     75%      max
# Class
# 0.0    86.017411  232.957939  0.0  7.3  22.88  77.675  7879.42
# 1.0    90.471165  247.173335  0.0  1.0   3.76  99.990  1809.68
#
# [2 rows x 240 columns]

# %%
ccd.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    24778.212797 -0.186787  0.044196   0.749331  0.176750 -0.209569
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.105912 -0.092989  0.025693  0.243321  ...  0.044683 -0.032046
# 1.0   -2.306085 -7.743100  3.867920 -2.961800  ...  0.652319  0.628539
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.111604 -0.040404  0.007159  0.135739  0.021382  0.007030  0.003658
# 1.0   -0.354537 -0.362138 -0.234731  0.300023  0.180390  0.822304  0.102481
#
#           Amount
# Class
# 0.0    86.017411
# 1.0    90.471165
#
# [2 rows x 30 columns]

# %%
# there's a significant difference in the mean value for our normal transaction and mean value for our fraud transactions
# now to balance the data for legit and fraud transaction value points
# we will use sampling for creating a new dataset of normal transactions with 492 entries being selected randomly out of 284315
normal_sample = legit.sample(n=492)

# %%
# now merge the two datasets for fraud and legit transactions with equal number of sampl points
new_dataset = pd.concat([normal_sample, fraud], axis = 0) # axis =0 species row wise joining of the datasets l

# %%
new_dataset
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 20107  30791  0.896849 -1.163703  1.060293  0.689355 -1.477791  0.603314
# 18420  29485  1.302567 -0.833113  1.061436 -0.676944 -1.693483 -0.554401
# 21271  31567  1.155629 -0.307500  1.105649  0.685864 -0.979439  0.175827
# 25317  33555  1.385351 -0.809159  0.258331 -1.195004 -0.394513  1.070846
# 30001  35733 -0.936155  0.459846  2.139647 -0.495435  0.748870 -0.688268
# ...      ...       ...       ...       ...       ...       ...       ...
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 20107 -1.057083  0.387176 -0.381934  ... -0.085028 -0.023088 -0.104616
# 18420 -1.216473  0.153532 -0.444687  ...  0.433498  1.080090 -0.077508
# 21271 -0.805439  0.301779  0.860971  ... -0.072646 -0.108959 -0.010896
# 25317 -1.193558  0.302124 -0.615835  ...  0.360436  0.997311 -0.315817
# 30001  0.714359 -0.113074 -0.341075  ... -0.209432 -0.653323 -0.118946
# ...         ...       ...       ...  ...       ...       ...       ...
# 30442 -6.805053  2.928356 -4.917130  ...  1.691042  0.920021 -0.151104
# 30473 -7.281328  3.332250 -3.679659  ...  1.550473  0.614573  0.028521
# 30496 -6.311699  3.449167 -5.416284  ...  1.194888 -0.845753  0.190674
# 31002 -6.958679  3.877795 -5.541529  ...  1.128641 -0.962960 -0.110045
# 33276 -5.283435  0.131619  0.658176  ... -0.734308 -0.599926 -4.908301
#
#             V24       V25       V26       V27       V28  Amount  Class
# 20107 -0.031414  0.184747 -0.239723  0.067556  0.050311  158.00    0.0
# 18420  0.550717  0.316564 -0.075500  0.022804  0.015832   19.00    0.0
# 21271  0.008906  0.229295  0.323289  0.005010  0.011782   11.50    0.0
# 25317 -1.641077  0.566231  0.066751  0.048538 -0.001887   24.99    0.0
# 30001  0.035444  0.113172  0.013850 -0.177914 -0.160155    1.29    0.0
# ...         ...       ...       ...       ...       ...     ...    ...
# 30442  0.011007  0.080303  0.412191  0.635789  0.501050    4.56    1.0
# 30473  0.013704 -0.149512 -0.131687  0.473934  0.473757   14.46    1.0
# 30496 -0.216443 -0.325033 -0.270328  0.210214  0.391855  111.70    1.0
# 31002 -0.177733 -0.089175 -0.049447  0.303445  0.219380  111.70    1.0
# 33276  0.410170 -1.167660  0.520508  1.937421 -1.552593   12.31    1.0
#
# [595 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    103
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    24736.784553 -0.137298  0.089874   0.790042  0.089079 -0.146387
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.103839 -0.026051  0.027979  0.273213  ...  0.062921 -0.061496
# 1.0   -2.306085 -7.743100  3.867920 -2.961800  ...  0.652319  0.628539
#
#             V22       V23       V24       V25      V26       V27       V28  \
# Class
# 0.0   -0.073003 -0.031911  0.030341  0.130433  0.02661  0.011625  0.014028
# 1.0   -0.354537 -0.362138 -0.234731  0.300023  0.18039  0.822304  0.102481
#
#           Amount
# Class
# 0.0    75.569370
# 1.0    90.471165
#
# [2 rows x 30 columns]

# %%
# here we can drop the time feature and instead use a derived column using timedelta function of pandas to represent the duration that is difference between two time values
delta_time = pd.to_timedelta(new_dataset['Time'], unit = 's')
# create the derived column
new_dataset['time_hour']=(delta_time.dt.components.hours).astype(int)
# now drop the time column
new_dataset.drop(columns='Time', axis=1, inplace = True)

# %%
new_dataset
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 20107  0.896849 -1.163703  1.060293  0.689355 -1.477791  0.603314 -1.057083
# 18420  1.302567 -0.833113  1.061436 -0.676944 -1.693483 -0.554401 -1.216473
# 21271  1.155629 -0.307500  1.105649  0.685864 -0.979439  0.175827 -0.805439
# 25317  1.385351 -0.809159  0.258331 -1.195004 -0.394513  1.070846 -1.193558
# 30001 -0.936155  0.459846  2.139647 -0.495435  0.748870 -0.688268  0.714359
# ...         ...       ...       ...       ...       ...       ...       ...
# 30442 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407 -6.805053
# 30473 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645 -7.281328
# 30496 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767 -6.311699
# 31002 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633 -6.958679
# 33276 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483 -5.283435
#
#              V8        V9       V10  ...       V22       V23       V24  \
# 20107  0.387176 -0.381934  0.828648  ... -0.023088 -0.104616 -0.031414
# 18420  0.153532 -0.444687  0.817702  ...  1.080090 -0.077508  0.550717
# 21271  0.301779  0.860971 -0.039389  ... -0.108959 -0.010896  0.008906
# 25317  0.302124 -0.615835  0.715591  ...  0.997311 -0.315817 -1.641077
# 30001 -0.113074 -0.341075 -0.625161  ... -0.653323 -0.118946  0.035444
# ...         ...       ...       ...  ...       ...       ...       ...
# 30442  2.928356 -4.917130 -6.600461  ...  0.920021 -0.151104  0.011007
# 30473  3.332250 -3.679659 -7.524368  ...  0.614573  0.028521  0.013704
# 30496  3.449167 -5.416284 -7.833556  ... -0.845753  0.190674 -0.216443
# 31002  3.877795 -5.541529 -7.502112  ... -0.962960 -0.110045 -0.177733
# 33276  0.131619  0.658176 -0.794994  ... -0.599926 -4.908301  0.410170
#
#             V25       V26       V27       V28  Amount  Class  time_hour
# 20107  0.184747 -0.239723  0.067556  0.050311  158.00    0.0          8
# 18420  0.316564 -0.075500  0.022804  0.015832   19.00    0.0          8
# 21271  0.229295  0.323289  0.005010  0.011782   11.50    0.0          8
# 25317  0.566231  0.066751  0.048538 -0.001887   24.99    0.0          9
# 30001  0.113172  0.013850 -0.177914 -0.160155    1.29    0.0          9
# ...         ...       ...       ...       ...     ...    ...        ...
# 30442  0.080303  0.412191  0.635789  0.501050    4.56    1.0          9
# 30473 -0.149512 -0.131687  0.473934  0.473757   14.46    1.0          9
# 30496 -0.325033 -0.270328  0.210214  0.391855  111.70    1.0          9
# 31002 -0.089175 -0.049447  0.303445  0.219380  111.70    1.0         10
# 33276 -1.167660  0.520508  1.937421 -1.552593   12.31    1.0         10
#
# [595 rows x 31 columns]

# %%
x = new_dataset.drop('Class', axis=1)

# %%
y = new_dataset['Class']

# %%
x.shape
# Out:
# (595, 30)

# %%
y.shape
# Out:
# (595,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 3, stratify = y)

# %%
#accumulating all the column names under one variable
cols = list(x.columns.values)

# %%
normal_entries = new_dataset.Class==0
fraud_entries = new_dataset.Class==1

plt.figure(figsize=(20,70))
for n, col in enumerate(cols):
    plt.subplot(10,3,n+1)
    sns.histplot(x[col][normal_entries], color='blue', kde = True, stat = 'density')
    sns.histplot(x[col][fraud_entries], color='red', kde = True, stat = 'density')
    plt.title(col, fontsize=17)
plt.show()

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_train)
pred_test = model.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# creating confusion matrix
from sklearn.metrics import confusion_matrix
def Plot_confusion_matrix(y_test, y_pred):
    cm = confusion_matrix(y_test,pred_test)
    plt.clf()
    plt.show()

# %%
# accuracy on training data
acc_score= round(accuracy_score(y_pred, y_train)*100,2)

# %%
print('the accuracy score for training data of our model is :', acc_score)
# Out:
# the accuracy score for training data of our model is : 99.33

# %%
y_pred = model.predict(x_test)
acc_score = round(accuracy_score(y_pred, y_test)*100,2)

# %%
print('the accuracy score of our model is :', acc_score)
# Out:
# the accuracy score of our model is : 97.99

# %%
from sklearn import metrics

# %%
score = round(model.score(x_test, y_test)*100,2)
print('score of our model is :', score)
# Out:
# score of our model is : 97.99

# %%
class_report = classification_report(y_pred, y_test)
print('classification report of our model: ', class_report)
# Out:
# classification report of our model:                precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99       126
#          1.0       0.88      1.00      0.94        23
#
#     accuracy                           0.98       149
#    macro avg       0.94      0.99      0.96       149
# weighted avg       0.98      0.98      0.98       149

# %%
# we have achieved a model with decent accuracy score
